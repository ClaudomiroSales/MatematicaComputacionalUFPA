# %% [markdown]
# Índice

# %% [markdown]
# - [Erros Absolutos e Relativos](#Erros-Absolutos-e-Relativos)
# - [Precisão dos dados e representação](#Precisão-dos-dados-e-representação)
#     - [Exemplo 1](#Exemplo-1)
#     - [Exemplo 2](#Exemplo-2)

# %%
pathFileImages = 'C:/Users/claud/Dropbox/RepoGit/Disciplina/Matemática Computacional/MatematicaComputacionalUFPAJupyter/Resolução de Sistemas Lineares/Figuras Linear/'


from IPython.display import Image
from IPython.display import HTML
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as npr
import math

# %% [markdown]
# # Exemplo de aplicação

# %%
Image(filename = pathFileImages + 'Fig_Intro_1.png')

# %%
Image(filename = pathFileImages + 'SysLinearEquations.png')

# %% [markdown]
# ## Exercício

# %%
#defs para plotar cada um dos casos acima

# %% [markdown]
# # Sistemas de Equações

# %%
Image(filename = pathFileImages + 'Fig_Intro_2.png')

# %%
Image(filename = pathFileImages + 'Fig_Intro_3.png')

# %%
Image(filename = pathFileImages + 'Fig_Intro_4.png')

# %% [markdown]
# ## Solução Única

# %%
Image(filename = pathFileImages + 'Fig_Intro_5_1.png')

# %%
Image(filename = pathFileImages + 'Fig_Intro_5_2.png')

# %% [markdown]
# <font size="+1"> Plote o sistema  </font>

# %% [markdown]
# ### Usando o numpy

# %%
Image(filename = pathFileImages + 'numpyLinalgSolve.png')

# %%
Image(filename = pathFileImages + 'numpyLinalgSolve2.png')

# %% [markdown]
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.linalg.solve.html

# %% [markdown]
# <font size="+1"> Resolva o sistema linear mostrado anteriormente  </font>

# %%
Image(filename = pathFileImages + 'planes.png')

# %% [markdown]
# <font size="+1"> Quantas equações e quantas variáveis?  </font>

# %% [markdown]
# ## Infinitas Soluções

# %%
Image(filename = pathFileImages + 'Fig_Intro_4_2.png')

# %% [markdown]
# ### Usando o numpy

# %% [markdown]
# <font size="+1"> Resolva e plote o sistema acima  </font>

# %% [markdown]
# ## Nenhuma Solução

# %%
Image(filename = pathFileImages + 'Fig_Intro_8.png')

# %% [markdown]
# ### Usando o numpy

# %% [markdown]
# <font size="+1"> Resolva e plote o sistema acima  </font>

# %% [markdown]
# <font size="+1"> Em resumo  </font>

# %%
Image(filename = pathFileImages + 'Fig_Intro_9.png')

# %% [markdown]
# # Matriz A

# %%
Image(filename = pathFileImages + 'Fig_Intro_4.png')

# %%
Image(filename = pathFileImages + 'Fig_Intro_10.png')

# %%
Image(filename = pathFileImages + 'Fig_Intro_11.png')

# %%
Image(filename = pathFileImages + 'Fig_Intro_12.png')

# %% [markdown]
# <font size="+1"> Relembrando multiplicação de matrizes  </font>

# %%
a  = np.matrix([[1, 2], [3, 4]])
b  = np.array([ [1, 2], [ 3 , 4] ])
print(a)
print(b)
c = a * b
print(c)
# Out:
# [[1 2]
#  [3 4]]
# [[1 2]
#  [3 4]]
# [[ 7 10]
#  [15 22]]

# %%
a  = np.matrix([[2, 1], [1, -3]])
print(a)


b  = np.array(   [1, 1]  )
print('b', b)
np.matmul(a.data, b)

#Faça para c
print('\nFaça para c')
# Out:
# [[ 2  1]
#  [ 1 -3]]
# b [1 1]
#
# Faça para c

# %%
Image(filename = pathFileImages + 'Fig_Intro_13.png')

# %% [markdown]
# <font size="+1"> Faça um def que recebe a matriz A e um vetor, e reproduza o gráfico acima  </font>
