# %% [markdown]
# Índice

# %% [markdown]
# - [Transformação do sistema linear](#Transformação-do-sistema-linear)
# - [Exemplo do método de Jacobi](#Exemplo-do-método-de-Jacobi)
# - [Critério de Convergência](#Critério-de-Convergência)
#     - [Teorema: critério da linhas](#Teorema:-critério-da-linhas)
#     - [Exemplo do critério das linhas ](#Exemplo-do-critério-das-linhas )
#         - [Exemplo A](#Exemplo-A)
#         - [Exemplo B](#Exemplo-B)
#         - [Exemplo C](#Exemplo-C)

# %%
pathFileImages = 'C:/Users/claud/Dropbox/RepoGit/Disciplina/Matemática Computacional/MatematicaComputacionalUFPAJupyter/Resolução de Sistemas Lineares/Figuras Método Iterativo de Jacobi/'


from IPython.display import Image
from IPython.display import HTML
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as npr
import math



#<font size="+2"> Usando o numpy  </font>

# %% [markdown]
# # Transformação do sistema linear

# %%
Image(filename = pathFileImages + 'Fig_1.png')

# %%
Image(filename = pathFileImages + 'Fig_1.png')

# %%
Image(filename = pathFileImages + 'Fig_1.png')

# %% [markdown]
# # Exemplo do método de Jacobi

# %%
Image(filename = pathFileImages + 'Fig_1.png')

# %%
Image(filename = pathFileImages + 'Fig_1.png')

# %%
Image(filename = pathFileImages + 'Fig_1.png')

# %% [markdown]
# # Critério de Convergência

# %%
Image(filename = pathFileImages + 'Fig_1.png')

# %%
Image(filename = pathFileImages + 'Fig_1.png')

# %%
Image(filename = pathFileImages + 'Fig_1.png')

# %% [markdown]
# ## Teorema: critério da linhas

# %% [markdown]
# ## Exemplo do critério das linhas

# %% [markdown]
# ### Exemplo A

# %% [markdown]
# ### Exemplo B

# %% [markdown]
# ### Exemplo C
