# %% [markdown]
# Índice

# %% [markdown]
# - [Definição](#Definição)
# - [Resolução de Sistemas Triangulares](#Resolução-de-Sistemas-Triangulares)
# - [Algoritmo I: resolução de um sistema triangular superior](#Algoritmo-I:-resolução-de-um-sistema-triangular-superior)
# - [Descrição do Método da Eliminação de Gauss](#Descrição-do-Método-da-Eliminação-de-Gauss)
#      - [Etapa 1](#Etapa-1)
#      - [Etapa 2](#Etapa-2)
#      - [Exemplo 1](#Exemplo-1)

# %%
pathFileImages = 'C:/Users/claud/Dropbox/RepoGit/Disciplina/Matemática Computacional/MatematicaComputacionalUFPAJupyter/Resolução de Sistemas Lineares/Figuras Intro Métodos Interativos/'


from IPython.display import Image
from IPython.display import HTML
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as npr
import math



#<font size="+3"> Usando o numpy  </font>

# %% [markdown]
# # Definição

# %%
Image(filename = pathFileImages + 'Fig_1.png')

# %% [markdown]
# # Teste de Parada

# %% [markdown]
# # Critério de Convergência

# %% [markdown]
# # Método de Gauss-Jacobi

# %% [markdown]
# <font size="+2"> Ou apenas Jacobi method  </font>

# %% [markdown]
# # Método de Gauss-Seidel

# %% [markdown]
# # Interpretação Geométrica
