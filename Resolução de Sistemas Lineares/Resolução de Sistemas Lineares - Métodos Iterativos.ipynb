# %% [markdown]
# Índice

# %% [markdown]
# - [Definição](#Definição)
# - [Teste de Parada](#Teste-de-Parada)
#     - [np.allClose](#np.allClose)
# - [Critério de Convergência](#Critério-de-Convergência)
# - [Descrição do Método da Eliminação de Gauss](#Descrição-do-Método-da-Eliminação-de-Gauss)
#      - [Etapa 1](#Etapa-1)
#      - [Etapa 2](#Etapa-2)
#      - [Exemplo 1](#Exemplo-1)

# %%
pathFileImages = 'C:/Users/claud/Dropbox/RepoGit/Disciplina/Matemática Computacional/MatematicaComputacionalUFPAJupyter/Resolução de Sistemas Lineares/Figuras Intro Métodos Interativos/'


from IPython.display import Image
from IPython.display import HTML
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as npr
import math



#<font size="+3"> Usando o numpy  </font>

# %% [markdown]
# # Definição

# %%
Image(filename = pathFileImages + 'Fig_1.png')

# %%
Image(filename = pathFileImages + 'Fig_2.png')

# %%
Image(filename = pathFileImages + 'Fig_3.png')

# %%
Image(filename = pathFileImages + 'Fig_4.png')

# %%
Image(filename = pathFileImages + 'Fig_5.png')

# %%
Image(filename = pathFileImages + 'Fig_6.png')

# %%
Image(filename = pathFileImages + 'Fig_7.png')

# %%
Image(filename = pathFileImages + 'Fig_8.png')

# %%
Image(filename = pathFileImages + 'Fig_9.png')

# %% [markdown]
# # Teste de Parada

# %%
Image(filename = pathFileImages + 'Fig_10.png')

# %%
Image(filename = pathFileImages + 'Fig_11.png')

# %%
Image(filename = pathFileImages + 'Fig_12.png')

# %%
Image(filename = pathFileImages + 'Fig_13.png')

# %% [markdown]
# ## np.allClose

# %% [markdown]
# https://docs.scipy.org/doc/numpy-1.15.1/reference/generated/numpy.allclose.html

# %%
Image(filename = pathFileImages + 'Fig_14.png')

# %%
Image(filename = pathFileImages + 'Fig_15.png')

# %%
ITERATION_LIMIT = 4 


x_sol = 1
x_K = 1.5#1.00004


atol = 0.0#1e-10
rtol = 0.34

print( 'Diferença relativa',  np.abs( x_sol - x_K ), '<=' ,rtol * x_K )
print( 'Diferença relativa',  np.abs( x_sol - x_K ), '<=' ,atol + rtol * x_K )

for it_count in range(ITERATION_LIMIT):
    if np.allclose(x_sol, x_K, rtol, atol):
        print('Solução ', x_K)
        break
# Out:
# Diferença relativa 0.5 <= 0.51
# Diferença relativa 0.5 <= 0.51
# Solução  1.5

# %%
def applyIterativeMethod( methodInt, rtol, A, b ):
    for it_count in range(ITERATION_LIMIT):
        
        np.append( x, ( methodInt( A, b ) ) )
        print("Iteration {0}: {1}".format(it_count, x[it_count]))
        
        if np.allclose(x[it_count], x[it_count-1], rtol, 0.0):
            print('Solução ', x[it_count])
            break
    
def jacobiMethod( A, b ):
    return
                  
def gaussSeidelMethod( A, b ):
    return

# %%
Image(filename = pathFileImages + 'Fig_9.png')

# %% [markdown]
# # Critério de Convergência

# %% [markdown]
# # Método de Gauss-Jacobi

# %% [markdown]
# <font size="+2"> Ou apenas Jacobi method  </font>

# %% [markdown]
# # Método de Gauss-Seidel

# %% [markdown]
# # Interpretação Geométrica
