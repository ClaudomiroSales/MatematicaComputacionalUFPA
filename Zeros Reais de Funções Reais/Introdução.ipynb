# %%
from IPython.display import Image

# %% [markdown]
# É comum em diversas áreas de ciências exatas resolvermos problemas que envolvem equações do tipo f(x) = 0.
# Considere o circuito abaixo por exemplo:

# %%
Image(filename = 'img/1.png')

# %% [markdown]
# O Objetivo deste capitulo é o estudo de de métodos que nos façam resolver problemas como o mostrado acima

# %% [markdown]
# Um número real & é um zero da função f(x) ou uma raiz da equação f(x) = 0 se f(&) = 0, sendo que estes podem ser reais ou complexos. No entando aqui daremos ênfase em números reais.

# %% [markdown]
# Zeros reais são representados por abscissas dos pontos onde uma curva intercepta o eixo x:

# %%
Image(filename = 'img/2.png')

# %% [markdown]
# Os métodos que iremos estudar contém duas fases:
#
#     - Localização ou isolamento das raizes
#     - Refinamento, ao melhorar uma aproximação com base no que foi encontrado na primeira fase
